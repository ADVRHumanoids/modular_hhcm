# %%
import os
import sys
from modular.URDF_writer import UrdfWriter

# %%
#create UrdfWriter object and joint map to store homing values
urdf_writer = UrdfWriter(speedup=True, floating_base=True)
homing_joint_map = {}
# Out:
# ResourceFinder initialized with config file: config_file.yaml
# ResourceFinder found the following resources paths: [['resources_path'], ['external_resources', 'concert_resources_path'], ['external_resources', 'dagana_path']]

# %%
#add mobile base
urdf_writer.add_module('concert/mobile_platform_concert.json', module_name='mobile_base')
# Out:
# {'name': 'mobile_base',
#  'type': <ModuleType.MOBILE_BASE: 'mobile_base'>,
#  'flange_size': '4',
#  'selected_connector': 'mobile_base_con1',
#  'selected_meshes': ['mobile_base_con1'],
#  'urdf_string': ''}

# %%
# leg + wheel 1
data = urdf_writer.select_module_from_name('mobile_base_con1')
wheel_data, steering_data = urdf_writer.add_wheel_module(wheel_filename='concert/module_wheel_concert.json', 
                                    steering_filename='concert/module_steering_concert_fl_rr.json')
homing_joint_map[str(steering_data['name'])] = 0.0
homing_joint_map[str(wheel_data['name'])] = 0.0

# leg + wheel 2
data = urdf_writer.select_module_from_name('mobile_base_con2')
wheel_data, steering_data = urdf_writer.add_wheel_module(wheel_filename='concert/module_wheel_concert.json', 
                                    steering_filename='concert/module_steering_concert_fr_rl.json')
homing_joint_map[str(steering_data['name'])] = 0.0
homing_joint_map[str(wheel_data['name'])] = 0.0

# leg + wheel 3
data = urdf_writer.select_module_from_name('mobile_base_con3')
wheel_data, steering_data = urdf_writer.add_wheel_module(wheel_filename='concert/module_wheel_concert.json', 
                                    steering_filename='concert/module_steering_concert_fr_rl.json')
homing_joint_map[str(steering_data['name'])] = 0.0
homing_joint_map[str(wheel_data['name'])] = 0.0

# leg + wheel 4
data = urdf_writer.select_module_from_name('mobile_base_con4')
wheel_data, steering_data = urdf_writer.add_wheel_module(wheel_filename='concert/module_wheel_concert.json', 
                                    steering_filename='concert/module_steering_concert_fl_rr.json')
homing_joint_map[str(steering_data['name'])] = 0.0
homing_joint_map[str(wheel_data['name'])] = 0.0

# %%
# manipulator
data = urdf_writer.select_module_from_name('mobile_base_con5')

# J1
data = urdf_writer.add_module('concert/module_joint_elbow_A_concert.json')
homing_joint_map[str(data['name'])] = {'angle': 0.5}

#add a 10cm passive link
data = urdf_writer.add_module('concert/module_link_straight_10_concert.json')

# J2
data = urdf_writer.add_module('concert/module_joint_elbow_B_concert.json')
homing_joint_map[str(data['name'])] = {'angle': -0.5}

#add a 20cm passive link
data = urdf_writer.add_module('concert/module_link_straight_20_concert.json')

# J3
data = urdf_writer.add_module('concert/module_joint_yaw_concert.json')
homing_joint_map[data['name']] = {'angle': 0.0}

# J4
data = urdf_writer.add_module('concert/module_joint_elbow_concert.json')
homing_joint_map[str(data['name'])] = {'angle': 0.5}

# J5
data = urdf_writer.add_module('concert/module_joint_elbow_concert.json')
homing_joint_map[str(data['name'])] = {'angle': -0.5}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/xbot2_ws/src/modular/src/modular/URDF_writer.py:1883, in UrdfWriter.add_module(self, filename, offsets, reverse, addons, robot_id, active_ports, is_structural, module_name)
#    1882 try:
# -> 1883     module_dict = self.modular_resources_manager.get_available_modules_dict()[filename]
#    1884     template_dict = self.modular_resources_manager.get_available_modules_dict()['template.yaml']
#
# KeyError: 'concert/module_joint_elbow_concert.json'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 5
#       2 data = urdf_writer.select_module_from_name('mobile_base_con5')
#       4 # J1
# ----> 5 data = urdf_writer.add_module('concert/module_joint_elbow_concert.json')
#       6 homing_joint_map[str(data['name'])] = {'angle': 0.5}
#       8 #add a 10cm passive link
#
# File ~/xbot2_ws/src/modular/src/modular/URDF_writer.py:1894, in UrdfWriter.add_module(self, filename, offsets, reverse, addons, robot_id, active_ports, is_structural, module_name)
#    1892         self.print("Module loaded from JSON: " + new_module.name)
#    1893 except KeyError:
# -> 1894     raise KeyError(filename+' was not found in the available resources')
#    1896 # Socket module is a custom type. It behaves differently from other link modules because it has no electronics onboard. Its parent should always be the base_link. On the hardware it will actually be connected to a non-structural hub, which therefore will not be part of the URDF, so we consider the base_link to be the parent in any case. This means the ports of the hub will not actually be occupied, so potentially there is no limit to how many sockets could be connected (>3).
#    1897 if new_module.type is ModuleType.SOCKET:
#
# KeyError: 'concert/module_joint_elbow_concert.json was not found in the available resources'

# %%
urdf_writer.remove_all_connectors()

# get srdf and joint_map
urdf_writer.write_urdf()
urdf_writer.write_lowlevel_config()
urdf_writer.write_problem_description_multi()
urdf_writer.write_srdf(homing_joint_map)
urdf_writer.write_joint_map()

# %%
# Save to file
# output_file = os.path.join(output_dir, robot_name)
# with open(output_file+".urdf", "w") as text_file:
#     text_file.write(urdf_string)
# with open(output_file+".srdf", "w") as text_file:
#     text_file.write(srdf_string)
print("All done! You can now deply the package using \033[3m\033[92m[path_to_modular]\033[0m\33[92m/src/modular/modular_data/deploy.sh\033[0m")

# %%
urdf_writer.deploy_robot("concert_robot_json")
